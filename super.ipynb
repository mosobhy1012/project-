# %%
import pandas as pd
data=pd.read_csv("supermarket_sales - Sheet1.csv")
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
data.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 66   838-78-4295      C  Naypyitaw        Normal  Female
# 274  477-24-6490      B   Mandalay        Normal  Female
# 432  459-50-7686      A     Yangon        Normal  Female
# 922  838-02-1821      C  Naypyitaw        Member  Female
# 363  462-67-9126      A     Yangon        Normal    Male
# 230  289-65-5721      B   Mandalay        Normal  Female
# 166  234-65-2137      C  Naypyitaw        Normal    Male
# 720  418-05-0656      B   Mandalay        Normal  Female
# 815  499-27-7781      B   Mandalay        Normal  Female
# 390  541-89-9860      C  Naypyitaw        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 66        Health and beauty       33.47         2   3.347    70.287
# 274       Health and beauty       99.71         6  29.913   628.173
# 432  Electronic accessories       23.46         6   7.038   147.798
# ...

# %%
data['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
data['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
data['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
data['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
data['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
pd.pivot_table(index=['Branch','City'],aggfunc='max',data=data)
# Out:
#                  Customer type      Date Gender   Invoice ID  Payment  \
# Branch City
# A      Yangon           Normal  3/9/2019   Male  898-04-2717  Ewallet
# B      Mandalay         Normal  3/9/2019   Male  895-66-0685  Ewallet
# C      Naypyitaw        Normal  3/9/2019   Male  894-41-5205  Ewallet
#
#                        Product line  Quantity  Rating  Tax 5%   Time    Total  \
# Branch City
# A      Yangon     Sports and travel        10    10.0   49.49  20:59  1039.29
# B      Mandalay   Sports and travel        10    10.0   48.69  20:57  1022.49
# C      Naypyitaw  Sports and travel        10    10.0   49.65  20:59  1042.65
#
#                   Unit price   cogs  gross income  gross margin percentage
# Branch City
# A      Yangon          99.83  989.8         49.49                 4.761905
# B      Mandalay        99.96  973.8         48.69                 4.761905
# C      Naypyitaw       99.96  993.0         49.65                 4.761905

# %%
pd.pivot_table(index=['Branch','City'],aggfunc='min',data=data)
# Out:
#                  Customer type      Date  Gender   Invoice ID Payment  \
# Branch City
# A      Yangon           Member  1/1/2019  Female  101-17-6199    Cash
# B      Mandalay         Member  1/1/2019  Female  109-28-2512    Cash
# C      Naypyitaw        Member  1/1/2019  Female  101-81-4070    Cash
#
#                             Product line  Quantity  Rating  Tax 5%   Time  \
# Branch City
# A      Yangon     Electronic accessories         1     4.0  0.6045  10:00
# B      Mandalay   Electronic accessories         1     4.0  0.8875  10:01
# C      Naypyitaw  Electronic accessories         1     4.0  0.5085  10:00
#
#                     Total  Unit price   cogs  gross income  \
# Branch City
# A      Yangon     12.6945       10.08  12.09        0.6045
# B      Mandalay   18.6375       10.59  17.75        0.8875
# C      Naypyitaw  10.6785       10.16  10.17        0.5085
#
#                   gross margin percentage
# Branch City
# A      Yangon                    4.761905
# ...

# %%
pd.pivot_table(index=['Branch','Payment','City'],aggfunc='max',data=data)
# Out:
#                              Customer type      Date Gender   Invoice ID  \
# Branch Payment     City
# A      Cash        Yangon           Normal  3/9/2019   Male  896-34-0956
#        Credit card Yangon           Normal  3/9/2019   Male  886-18-2897
#        Ewallet     Yangon           Normal  3/9/2019   Male  898-04-2717
# B      Cash        Mandalay         Normal  3/9/2019   Male  895-03-6665
#        Credit card Mandalay         Normal  3/9/2019   Male  889-04-9723
#        Ewallet     Mandalay         Normal  3/9/2019   Male  895-66-0685
# C      Cash        Naypyitaw        Normal  3/9/2019   Male  885-56-0389
#        Credit card Naypyitaw        Normal  3/8/2019   Male  894-41-5205
#        Ewallet     Naypyitaw        Normal  3/8/2019   Male  886-77-9084
#
#                                    Product line  Quantity  Rating  Tax 5%  \
# Branch Payment     City
# A      Cash        Yangon     Sports and travel        10     9.9  44.397
# ...

# %%
pd.pivot_table(index=['Branch','Payment','City'],aggfunc='min',data=data)
# Out:
#                              Customer type       Date  Gender   Invoice ID  \
# Branch Payment     City
# A      Cash        Yangon           Member   1/1/2019  Female  106-35-6779
#        Credit card Yangon           Member   1/1/2019  Female  101-17-6199
#        Ewallet     Yangon           Member   1/1/2019  Female  105-10-6182
# B      Cash        Mandalay         Member   1/1/2019  Female  110-48-7033
#        Credit card Mandalay         Member   1/1/2019  Female  109-86-4363
#        Ewallet     Mandalay         Member  1/10/2019  Female  109-28-2512
# C      Cash        Naypyitaw        Member   1/1/2019  Female  102-06-2002
#        Credit card Naypyitaw        Member   1/1/2019  Female  102-77-2261
#        Ewallet     Naypyitaw        Member   1/1/2019  Female  101-81-4070
#
#                                         Product line  Quantity  Rating  \
# Branch Payment     City
# A      Cash        Yangon     Electronic accessories         1     4.1
# ...

# %%
pd.pivot_table(index=['Gender','Product line','Payment'],aggfunc='min',data=data)
# Out:
#                                           Branch      City Customer type  \
# Gender Product line           Payment
# Female Electronic accessories Cash             A  Mandalay        Member
#                               Credit card      A  Mandalay        Member
#                               Ewallet          A  Mandalay        Member
#        Fashion accessories    Cash             A  Mandalay        Member
#                               Credit card      A  Mandalay        Member
#                               Ewallet          A  Mandalay        Member
#        Food and beverages     Cash             A  Mandalay        Member
#                               Credit card      A  Mandalay        Member
#                               Ewallet          A  Mandalay        Member
#        Health and beauty      Cash             A  Mandalay        Member
#                               Credit card      A  Mandalay        Member
# ...

# %%
pd.pivot_table(index=['Customer type','Gender'],aggfunc='max',data=data)
# Out:
#                      Branch    City      Date   Invoice ID  Payment  \
# Customer type Gender
# Member        Female      C  Yangon  3/9/2019  891-58-8335  Ewallet
#               Male        C  Yangon  3/9/2019  895-66-0685  Ewallet
# Normal        Female      C  Yangon  3/9/2019  895-03-6665  Ewallet
#               Male        C  Yangon  3/9/2019  898-04-2717  Ewallet
#
#                            Product line  Quantity  Rating  Tax 5%   Time  \
# Customer type Gender
# Member        Female  Sports and travel        10    10.0   49.65  20:55
#               Male    Sports and travel        10     9.9   45.25  20:59
# Normal        Female  Sports and travel        10    10.0   48.69  20:59
#               Male    Sports and travel        10    10.0   49.49  20:57
#
#                         Total  Unit price   cogs  gross income  \
# Customer type Gender
# Member        Female  1042.65       99.60  993.0         49.65
# ...

# %%
pd.pivot_table(index=['Customer type','Gender'],aggfunc='min',data=data)
# Out:
#                      Branch      City      Date   Invoice ID Payment  \
# Customer type Gender
# Member        Female      A  Mandalay  1/1/2019  101-81-4070    Cash
#               Male        A  Mandalay  1/1/2019  102-06-2002    Cash
# Normal        Female      A  Mandalay  1/1/2019  110-05-6330    Cash
#               Male        A  Mandalay  1/1/2019  101-17-6199    Cash
#
#                                 Product line  Quantity  Rating  Tax 5%   Time  \
# Customer type Gender
# Member        Female  Electronic accessories         1     4.0  0.6270  10:00
#               Male    Electronic accessories         1     4.0  0.5085  10:00
# Normal        Female  Electronic accessories         1     4.0  0.6045  10:01
#               Male    Electronic accessories         1     4.0  0.6390  10:00
#
#                         Total  Unit price   cogs  gross income  \
# Customer type Gender
# Member        Female  13.1670       10.16  12.54        0.6270
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
sns.countplot(data['Gender'].value_counts().index)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(data['Payment'].value_counts().index)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(data['City'].value_counts().index)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
data.groupby('City').count()['Rating'].plot()
# Out:
# <AxesSubplot:xlabel='City'>

# %%
plt.figure(figsize=(15,10))
data.groupby('Branch').count()['Payment'].plot()
# Out:
# <AxesSubplot:xlabel='Branch'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>
